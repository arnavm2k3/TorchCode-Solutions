# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavm2k3/TorchCode-Solutions/blob/main/templates/22_conv2d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟠 Medium: 2D Convolution
#
# Implement **2D convolution** from scratch.
#
# ### Signature
# ```python
# def my_conv2d(x, weight, bias=None, stride=1, padding=0):
#     # x: (B, C_in, H, W), weight: (C_out, C_in, kH, kW)
#     # Returns: (B, C_out, H_out, W_out)
# ```
#
# ### Rules
# - Do NOT use `F.conv2d` or `nn.Conv2d`
# - Support `stride` and `padding` parameters
# - `F.pad` for zero-padding is allowed

# %%
pass  # Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.6 MB/s eta 0:00:00

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def my_conv2d(x, weight, bias=None, stride=1, padding=0):
    C_out, C_in, kH, kW = weight.size()
    x_pad = F.pad(x, (padding, padding, padding, padding))
    patches = x_pad.unfold(2, kH, stride).unfold(3, kW, stride)
    # patches: (b, c_in, h_out, w_out, kH, kW)
    out = torch.einsum('bihwkl,oikl->bohw', patches, weight)
    if bias is not None:
        out += bias.view(1, -1, 1, 1)
    return out

# %%
# 🧪 Debug
x = torch.randn(1, 3, 8, 8)
w = torch.randn(16, 3, 3, 3)
print('Output:', my_conv2d(x, w).shape)
print('Match:', torch.allclose(my_conv2d(x, w), F.conv2d(x, w), atol=1e-4))
# Out:
# Output: torch.Size([1, 16, 6, 6])
# Match: True

# %%
# ✅ SUBMIT
from torch_judge import check
check('conv2d')
# Out:
# 🧪 Testing: 2D Convolution (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/5] Output shape (1.0ms)
#   ✅ [2/5] Matches F.conv2d (114.4ms)
#   ✅ [3/5] With padding (4.7ms)
#   ✅ [4/5] With stride (1.8ms)
#   ✅ [5/5] Gradient flow (18.9ms)
# ──────────────────────────────────────────────────
#   🎉 All 5 tests passed! (140.7ms total)
#   Progress saved. Run status() to see your dashboard.
