# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavm2k3/TorchCode-Solutions/blob/main/templates/20_weight_init.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟢 Easy: Kaiming Initialization
#
# Implement **Kaiming (He) normal initialization** for weight tensors.
#
# $$W \sim \mathcal{N}(0, \text{std}^2) \quad \text{where} \quad \text{std} = \sqrt{\frac{2}{\text{fan\_in}}}$$
#
# ### Signature
# ```python
# def kaiming_init(weight: Tensor) -> Tensor:
#     # Initialize weight in-place with Kaiming normal
#     # fan_in = weight.shape[1]
#     # Returns the weight tensor
# ```
#
# ### References
# Kaiming He Initilization - [Link](https://medium.com/@shauryagoel/kaiming-he-initialization-a8d9ed0b5899)

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.3 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def kaiming_init(weight):
    # fill with normal(0, sqrt(2/fan_in))

    fan_in = weight.size(1)
    std = math.sqrt(2.0/fan_in)
    with torch.no_grad():
      weight.normal_(0, std )
    return weight

# %%
# 🧪 Debug
import math
w = torch.empty(256, 512)
kaiming_init(w)
print(f'Mean: {w.mean():.4f} (expect ~0)')
print(f'Std:  {w.std():.4f} (expect {math.sqrt(2/512):.4f})')
# Out:
# Mean: -0.0002 (expect ~0)
# Std:  0.0627 (expect 0.0625)

# %%
# ✅ SUBMIT
from torch_judge import check
check('weight_init')
# Out:
# 🧪 Testing: Kaiming Initialization (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Mean approximately 0 (4.2ms)
#   ✅ [2/4] Std matches sqrt(2/fan_in) (5.1ms)
#   ✅ [3/4] Returns same tensor (in-place) (0.3ms)
#   ✅ [4/4] Smaller fan_in gives larger std (0.5ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (10.0ms total)
#   Progress saved. Run status() to see your dashboard.
