# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavm2k3/TorchCode-Solutions/blob/main/templates/21_gradient_clipping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟢 Easy: Gradient Norm Clipping
#
# Implement **gradient norm clipping** — a training stability technique.
#
# ### Signature
# ```python
# def clip_grad_norm(parameters, max_norm: float) -> float:
#     # Clip gradients in-place so total norm <= max_norm
#     # Returns the original (unclipped) total norm
# ```
#
# ### Algorithm
# 1. Compute total norm: `sqrt(sum(p.grad.norm()^2 for p in parameters))`
# 2. If total > max_norm: scale all grads by `max_norm / total`
# 3. Return original total norm
#
# ### References
# Vanishing and Exploding Gradients - [Link](https://medium.com/@seyiakinsanya3/vanishing-and-exploding-gradients-problems-in-deep-learning-e6a1591a1c44)

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.8 MB/s eta 0:00:00

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def clip_grad_norm(parameters, max_norm):
    # compute total norm, clip if needed, return original norm
    total_norm = torch.sqrt(torch.sum(torch.tensor([torch.pow(p.grad.norm(), 2) for p in parameters])))
    clip_coef = max_norm / total_norm

    if clip_coef <= 1:
      parameters = [p.grad.mul_(clip_coef) for p in parameters]

    return total_norm

# %%
# 🧪 Debug
p = torch.randn(100, requires_grad=True)
(p * 10).sum().backward()
print('Before:', p.grad.norm().item())
orig = clip_grad_norm([p], max_norm=1.0)
print('After: ', p.grad.norm().item())
print('Original norm:', orig)
# Out:
# Before: 100.0
# After:  0.9999999403953552
# Original norm: tensor(100.)

# %%
# ✅ SUBMIT
from torch_judge import check
check('gradient_clipping')
# Out:
# 🧪 Testing: Gradient Norm Clipping (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Clips to max_norm (3.3ms)
#   ✅ [2/4] Returns original norm (1.6ms)
#   ✅ [3/4] No change when norm < max_norm (1.6ms)
#   ✅ [4/4] Preserves direction (6.0ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (12.5ms total)
#   Progress saved. Run status() to see your dashboard.
