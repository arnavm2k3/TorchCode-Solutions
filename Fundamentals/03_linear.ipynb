# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavm2k3/TorchCode-Solutions/blob/main/templates/03_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # 🟡 Medium: Simple Linear Layer
#
# Implement a fully-connected linear layer: **y = xW^T + b**
#
# ### Signature
# ```python
# class SimpleLinear:
#     def __init__(self, in_features: int, out_features: int): ...
#     def forward(self, x: torch.Tensor) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - `self.weight`: shape `(out_features, in_features)`, init with `randn * (1/√in_features)`
# - `self.bias`: shape `(out_features,)`, init as zeros
# - Both must have `requires_grad=True`
# - `forward(x)` computes `x @ W^T + b`
# - Do **NOT** use `torch.nn.Linear`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.4 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class SimpleLinear:
    def __init__(self, in_features: int, out_features: int):
        # Initialize weight and bias
        std = math.sqrt(2.0 / in_features)
        self.weight = torch.empty(out_features, in_features)
        self.weight.normal_(0, std)
        self.bias = torch.zeros(out_features, )

        self.weight.requires_grad_()
        self.bias.requires_grad_()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Compute y = x @ W^T + b
        y = torch.matmul(x, torch.transpose(self.weight, 0, 1)) + self.bias
        return y

# %%
# 🧪 Debug
layer = SimpleLinear(8, 4)
print("W shape:", layer.weight.shape)  # should be (4, 8)
print("b shape:", layer.bias.shape)    # should be (4,)

x = torch.randn(2, 8)
y = layer.forward(x)
print("Output shape:", y.shape)        # should be (2, 4)
# Out:
# W shape: torch.Size([4, 8])
# b shape: torch.Size([4])
# Output shape: torch.Size([2, 4])

# %%
# ✅ SUBMIT
from torch_judge import check
check("linear")
# Out:
# 🧪 Testing: Simple Linear Layer (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Weight & bias shape (1.1ms)
#   ✅ [2/3] Forward pass (26.7ms)
#   ✅ [3/3] Gradient flow (3.9ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (31.7ms total)
#   Progress saved. Run status() to see your dashboard.
