# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavm2k3/TorchCode-Solutions/blob/main/Training_Optimization/30_cosine_lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟠 Medium: Cosine LR Scheduler with Warmup
#
# Implement a **cosine learning rate schedule** with linear warmup.
#
# ### Signature
# ```python
# def cosine_lr_schedule(step, total_steps, warmup_steps, max_lr, min_lr=0.0) -> float:
# ```
#
# ### Schedule
# ```
# step < warmup:  lr = max_lr * step / warmup_steps  (linear ramp)
# step >= warmup: lr = min_lr + 0.5*(max_lr-min_lr)*(1 + cos(π * progress))
# ```
# where `progress = (step - warmup) / (total - warmup)`
#
# ### References
# Cosine LR Scheduler - [Link](https://medium.com/@utkrisht14/cosine-learning-rate-schedulers-in-pytorch-486d8717d541)

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.3 MB/s eta 0:00:00

# %%
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def cosine_lr_schedule(step, total_steps, warmup_steps, max_lr, min_lr=0.0):
  # warmup then cosine decay

  if step < warmup_steps:
    return max_lr * step / warmup_steps
  else:
    progress = (step - warmup_steps) / (total_steps - warmup_steps)
    return min_lr + 0.5 * (max_lr - min_lr) * (1 + math.cos(math.pi * progress))

# %%
# 🧪 Debug
lrs = [cosine_lr_schedule(i, 100, 10, 0.001) for i in range(101)]
print(f'Start: {lrs[0]:.6f}')
print(f'Warmup end: {lrs[10]:.6f}')
print(f'Mid: {lrs[55]:.6f}')
print(f'End: {lrs[100]:.6f}')
# Out:
# Start: 0.000000
# Warmup end: 0.001000
# Mid: 0.000500
# End: 0.000000

# %%
# ✅ SUBMIT
from torch_judge import check
check('cosine_lr')
# Out:
# 🧪 Testing: Cosine LR Scheduler with Warmup (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/5] Start of warmup (0.2ms)
#   ✅ [2/5] End of warmup (0.1ms)
#   ✅ [3/5] End of schedule (0.1ms)
#   ✅ [4/5] Warmup is monotonically increasing (0.2ms)
#   ✅ [5/5] Cosine shape (0.1ms)
# ──────────────────────────────────────────────────
#   🎉 All 5 tests passed! (0.7ms total)
#   Progress saved. Run status() to see your dashboard.
